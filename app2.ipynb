# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("data/conteo_union.csv")
df.Sucursal.unique()
# Out:
# array(['TOLIMA', 'BOGOTA D.C.', 'ATLANTICO', 'VALLE DEL CAUCA',
#        'NORTE DE SANTANDER', 'QUINDIO', 'SANTANDER', 'RISARALDA',
#        'CUNDINAMARCA', 'SUCRE', 'HUILA', 'ANTIOQUIA', 'CAQUETA', 'BOYACA',
#        'PUTUMAYO', 'NARIÑO', 'BOLIVAR', 'META', 'MAGDALENA', 'CESAR',
#        'CALDAS', 'CAUCA', 'CASANARE', 'NO DISPONIBLE'], dtype=object)

# %%
fallecidos_dane = pd.read_csv('data/Fallecimientos_por_depto_DANE_2015_2021_7_deptos.csv')
fallecidos_dane.DEPARTAMENTO.unique()
# Out:
# array(['ATLANTICO', 'BOGOTA D.C.', 'SANTANDER', 'VALLE DEL CAUCA',
#        'TOLIMA', 'HUILA', 'NARIÑO'], dtype=object)

# %%
fallecidos_copy = fallecidos_dane.copy()
fallecidos_dep =fallecidos_copy[fallecidos_copy['DEPARTAMENTO'].isin(['TOLIMA', 'ATLANTICO'])]
fal_dane_anio = fallecidos_dep.groupby(["anio", 'DEPARTAMENTO']).size().reset_index()
fal_dane_anio.columns= ["AÑO", 'DEPARTAMENTO', "Total_fallecidos"]
fal_dane_anio

fig = px.bar(fal_dane_anio,x="AÑO",y="Total_fallecidos" , color='DEPARTAMENTO')
fig.show()

# %%
df_benef = pd.read_csv('data/Conteo_Anual_Mens_Ubic_EdadPop.csv')
df_benef.Sucursal.unique()
# Out:
# array(['TOLIMA', 'BOGOTA D.C.', 'ATLANTICO', 'VALLE DEL CAUCA',
#        'NORTE DE SANTANDER', 'QUINDIO', 'SANTANDER', 'RISARALDA',
#        'CUNDINAMARCA', 'SUCRE', 'HUILA', 'ANTIOQUIA', 'CAQUETA', 'BOYACA',
#        'PUTUMAYO', 'NARIÑO', 'BOLIVAR', 'META', 'MAGDALENA', 'CESAR',
#        'CALDAS', 'CAUCA', 'CASANARE', 'NO DISPONIBLE'], dtype=object)

# %%
df2 = df_benef[df_benef['Sucursal'].isin(['TOLIMA', 'ATLANTICO'])]
fig = px.line(df2, x='Year_Month', y="Proporcion_Siniestros",color='Sucursal', hover_name='Rango_Edad')
fig.show(0)
